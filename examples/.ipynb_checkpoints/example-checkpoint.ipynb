# %%
import sys
import os

# Go up one directory from the notebook's location to the project root
project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))

# Add the project root to the Python path if it's not already there
if project_root not in sys.path:
    sys.path.append(project_root)
    print(f"Added '{project_root}' to the Python path")

# Now you can import from 'src' as if it were a package
from src.constrained_diffusion import constrained_diffusion_decomposition
# Out:
# Added '/Users/gxli/proj/GitHub/Constrained-Diffusion-Decomposition' to the Python path

# %%
import matplotlib.pyplot as plt
from matplotlib import cm
import numpy as np

def multivariate_gaussian(pos, mu, Sigma):
    """Return the multivariate Gaussian distribution on array pos.

    pos is an array constructed by packing the meshed arrays of variables
    x_1, x_2, x_3, ..., x_k into its _last_ dimension.

    """

    n = mu.shape[0]
    Sigma_det = np.linalg.det(Sigma)
    Sigma_inv = np.linalg.inv(Sigma)
    N = np.sqrt((2*np.pi)**n * Sigma_det)

    fac = np.einsum('...k,kl,...l->...', pos-mu, Sigma_inv, pos-mu)

    return np.exp(-fac / 2) / N

# %%
# Preparing sample input
N_x = 300
N_y = 200
X = np.linspace(0, 300, N_x)
Y = np.linspace(0, 200, N_y)
X, Y = np.meshgrid(X, Y)

mu = np.array([150., 100.])
Sigma = np.array([[200, 0], [0,  200]])

pos = np.empty(X.shape + (2,))
pos[:, :, 0] = X
pos[:, :, 1] = Y


Z1 = multivariate_gaussian(pos, mu, Sigma) * 100
Z3 = multivariate_gaussian(pos, mu - 10 , Sigma * 0.03) * 3

Z = Z1 + Z3

plt.figure()
plt.imshow(Z)
plt.colorbar()
plt.show()

# %%
# performing decomposition
result, residual, scales = constrained_diffusion_decomposition(Z,up_sample=True, return_scales=True)
# Out:
# Automatically determined max_scale = 150.00 (from data shape (200, 300))
# Automatically determining num_channels for log mode.
# --> Determined num_channels = 7
#
# --- STAGE 1: Performing high-resolution decomposition for scales <= 5.0 ---
# Decomposing across 2 user-specified scales: [4.   9.22]
# Running in CONSTRAINED (standard) mode.
# Channel 0: Scale < 4.00 pixels, Iterations: 33
# Channel 1: Scale < 9.22 pixels, Iterations: 144
# Downsampling small-scale results...
#
# --- STAGE 2: Performing fixed-grid decomposition on residual for scales > 5.0 ---
# Decomposing across 5 user-specified scales: [  5.31  12.25  28.23  65.07 150.  ]
# Running in CONSTRAINED (standard) mode.
# Channel 0: Scale < 5.31 pixels, Iterations: 33
# Channel 1: Scale < 12.25 pixels, Iterations: 144
# Channel 2: Scale < 28.23 pixels, Iterations: 144
# Channel 3: Scale < 65.07 pixels, Iterations: 144
# Channel 4: Scale < 150.00 pixels, Iterations: 144

# %%
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.axes_grid1.inset_locator import inset_axes

# Assuming 'result' is a list of 2D arrays
# Example: result = [np.random.rand(10, 10) for _ in range(6)]  # Dummy data for testing
n_images = len(result)
cols = 3  # Fixed number of columns
rows = int(np.ceil(n_images / cols))  # Calculate required rows

# Determine the global min and max for the shared color scale
vmin = min(np.min(img) for img in result)
vmax = max(np.max(img) for img in result)

# Create a figure with a grid of subplots
fig, axes = plt.subplots(rows, cols, figsize=(4 * cols, 4 * rows), squeeze=False)
axes = axes.flatten()  # Flatten for easier iteration

# Plot each image in the grid
for idx, img in enumerate(result):
    ax = axes[idx]
    im = ax.imshow(img, cmap='viridis', vmin=vmin, vmax=vmax)  # Use shared color scale
    ax.set_title(f'Image {idx + 1}')  # Add title for clarity
    ax.axis('on')  # Show axes (can be turned off with ax.axis('off') if desired)

    # Add colorbar only to the first subplot (top-left)
    if idx == 0:
        # Create an inset axes for the colorbar inside the first subplot
        cax = inset_axes(ax, width="5%", height="50%", loc='lower right',
                         bbox_to_anchor=(0, 0, 1, 1), bbox_transform=ax.transAxes)
        fig.colorbar(im, cax=cax)  # Add colorbar to inset axes

# Hide empty subplots if any
for idx in range(len(result), len(axes)):
    axes[idx].set_visible(False)

# Adjust layout to prevent overlap
plt.tight_layout()
plt.show()
# Out:
# /var/folders/t_/1c6q66gn5jqg62hwxfkjlb380000gn/T/ipykernel_56439/333816702.py:38: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %%
"""
This script provides a comprehensive set of examples for the
`constrained_diffusion_decomposition` function.

The examples are ordered to highlight key features:
1.  Constrained vs. Unconstrained (1D): Shows how the constraint removes artifacts.
2.  Inverted vs. Standard (1D): Shows how to extract negative features ("holes").
3.  Upsampled vs. Fixed-Grid (1D): Shows how upsampling improves detail resolution.
4.  Unconstrained (2D): Visualizes the ringing artifacts in 2D.
5.  Constrained (2D): Shows the clean, recommended 2D decomposition result.
"""
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1.inset_locator import inset_axes
import sys
import os

# =============================================================================
# DYNAMIC IMPORT BLOCK
# =============================================================================
try:
    from constrained_diffusion import constrained_diffusion_decomposition
except ModuleNotFoundError:
    current_dir = os.path.dirname(os.path.abspath(__file__))
    src_path = os.path.join(current_dir, '..', 'src')
    sys.path.append(src_path)
    print(f"Added to path: {src_path}")
    from constrained_diffusion import constrained_diffusion_decomposition

# =============================================================================
# Helper Functions for Plotting
# =============================================================================

def plot_comparison_1d(original, res1, res2, resid1, resid2, scales, title, label1, label2):
    """
    Generic 1D comparison plotter. Result 1 is SOLID, Result 2 is DASHED.
    """
    fig, ax = plt.subplots(figsize=(12, 9))
    fig.suptitle(title, fontsize=16)
    ax.plot(original, 'k-', label='Original Signal', linewidth=2.5, zorder=10)
    colors = plt.cm.viridis(np.linspace(0, 1, len(res1) + 1))
    shift_amount = np.max(np.abs(original)) * 1.0

    for i in range(len(res1)):
        shift = (i + 1) * shift_amount
        color = colors[i]
        ax.plot(res1[i] - shift, color=color, linestyle='-', label=f'Ch {i} ({label1})', linewidth=1.5)
        ax.plot(res2[i] - shift, color=color, linestyle='--', label=f'Ch {i} ({label2})', linewidth=1.5)

    resid_shift = (len(res1) + 1) * shift_amount
    ax.plot(resid1 - resid_shift, color='blue', linestyle='-', label=f'Residual ({label1})')
    ax.plot(resid2 - resid_shift, color='blue', linestyle='--', label=f'Residual ({label2})')

    handles, labels = ax.get_legend_handles_labels()
    unique_labels = dict(zip(labels, handles))
    ax.legend(unique_labels.values(), unique_labels.keys(), loc='upper right')
    
    ax.grid(True, linestyle='--', alpha=0.6)
    ax.set_title('Decomposition Channels (Vertically Shifted for Clarity)')
    ax.set_xlabel('Signal Index')
    ax.set_yticks([])
    ax.set_ylabel('Component Amplitude (Shifted)')
    plt.tight_layout(rect=[0, 0.03, 1, 0.95])
    plt.show()

def plot_decomposition_2d(original, results, residual, scales, title):
    """
    Plots a single 2D decomposition result using the 'seismic' colormap
    and precise scale ranges in the titles.
    """
    all_components = [original] + results + [residual]
    v_abs = max(abs(arr.min()) for arr in all_components)
    v_abs = max(v_abs, max(abs(arr.max()) for arr in all_components))
    vmin, vmax = -v_abs, v_abs
    
    num_plots = len(results) + 2
    cols = int(np.ceil(np.sqrt(num_plots)))
    rows = int(np.ceil(num_plots / cols))
    
    fig, axes = plt.subplots(rows, cols, figsize=(cols * 4.5, rows * 4))
    axes = axes.flatten()
    fig.suptitle(title, fontsize=16)

    # --- Create plot info with new, more descriptive titles ---
    plot_info = [('Original Image', original)]
    lower_bounds = [0.0] + list(scales[:-1]) # Lower bound for each channel

    for i, channel in enumerate(results):
        lower = lower_bounds[i]
        upper = scales[i]
        channel_title = f'{lower:.1f} < Scale < {upper:.1f}'
        plot_info.append((channel_title, channel))
    
    plot_info.append(('Residual', residual))

    # --- Plotting loop ---
    im = None
    for i, (plot_title, data) in enumerate(plot_info):
        im = axes[i].imshow(data, cmap='seismic', vmin=vmin, vmax=vmax)
        axes[i].set_title(plot_title)
        axes[i].set_xticks([]); axes[i].set_yticks([])

    if im:
        cax = inset_axes(axes[0], width="5%", height="50%", loc='upper right')
        fig.colorbar(im, cax=cax, orientation="vertical")

    for i in range(num_plots, len(axes)):
        axes[i].axis('off')
    
    plt.tight_layout(rect=[0, 0.03, 1, 0.95])
    plt.show()

# =============================================================================
# Signal and Image Generation
# =============================================================================
def gaussian(x, mu, sig):
    return np.exp(-np.power(x - mu, 2.) / (2 * np.power(sig, 2.)))

x_1d = np.linspace(0, 500, 500)
signal_1d = (gaussian(x_1d, 100, 5) + gaussian(x_1d, 250, 15) + gaussian(x_1d, 400, 30))
signal_inverted = gaussian(x_1d, 250, 40) - 0.7 * gaussian(x_1d, 250, 8)
y_2d, x_2d = np.mgrid[0:128, 0:128]
image_2d = (gaussian(np.sqrt((x_2d-40)**2 + (y_2d-40)**2), 0, 3) + 
            gaussian(np.sqrt((x_2d-90)**2 + (y_2d-90)**2), 0, 20))

# %%
# =============================================================================
# TEST CASES (REORDERED)
# =============================================================================

# --- Test Case 1: Constrained vs. Unconstrained Decomposition (1D) ---
print("--- Running Test Case 1: Constrained vs. Unconstrained (1D Log) ---")
res_con, resid_con, sc = constrained_diffusion_decomposition(
    data=signal_1d, max_scale=40, mode='log', constrained=True, up_sample=True, return_scales=True)
res_uncon, resid_uncon, _ = constrained_diffusion_decomposition(
    data=signal_1d, max_scale=40, mode='log', constrained=False, up_sample=True, return_scales=True)
plot_comparison_1d(signal_1d, res_con, res_uncon, resid_con, resid_uncon, sc,
                   'Constrained vs. Unconstrained (1D Log)', 'Constrained', 'Unconstrained')
# Out:
# --- Running Test Case 1: Constrained vs. Unconstrained (1D Log) ---
# Automatically determining num_channels for log mode.
# --> Determined num_channels = 5
#
# --- STAGE 1: Performing high-resolution decomposition for scales <= 5.0 ---
# Decomposing across 2 user-specified scales: [ 4.   10.06]
# Running in CONSTRAINED (standard) mode.
# Channel 0: Scale < 4.00 pixels, Iterations: 33
# Channel 1: Scale < 10.06 pixels, Iterations: 177
# Downsampling small-scale results...
#
# --- STAGE 2: Performing fixed-grid decomposition on residual for scales > 5.0 ---
# Decomposing across 3 user-specified scales: [ 6.32 15.91 40.  ]
# Running in CONSTRAINED (standard) mode.
# Channel 0: Scale < 6.32 pixels, Iterations: 33
# Channel 1: Scale < 15.91 pixels, Iterations: 177
# Channel 2: Scale < 40.00 pixels, Iterations: 177
# Automatically determining num_channels for log mode.
# --> Determined num_channels = 5
#
# --- STAGE 1: Performing high-resolution decomposition for scales <= 5.0 ---
# Decomposing across 2 user-specified scales: [ 4.   10.06]
# Running in UNCONSTRAINED (linear diffusion) mode.
# Channel 0: Scale < 4.00 pixels, Iterations: 33
# Channel 1: Scale < 10.06 pixels, Iterations: 177
# Downsampling small-scale results...
#
# --- STAGE 2: Performing fixed-grid decomposition on residual for scales > 5.0 ---
# Decomposing across 3 user-specified scales: [ 6.32 15.91 40.  ]
# Running in UNCONSTRAINED (linear diffusion) mode.
# Channel 0: Scale < 6.32 pixels, Iterations: 33
# Channel 1: Scale < 15.91 pixels, Iterations: 177
# Channel 2: Scale < 40.00 pixels, Iterations: 177

# %%
# --- Test Case 2: Inverted vs. Standard Decomposition ---
print("\n--- Running Test Case 2: Inverted vs. Standard (1D Log) ---")
res_std, resid_std, sc = constrained_diffusion_decomposition(
    data=signal_inverted, max_scale=50, mode='log', inverted=False, up_sample=True, return_scales=True)
res_inv, resid_inv, _ = constrained_diffusion_decomposition(
    data=signal_inverted, max_scale=50, mode='log', inverted=True, up_sample=True, return_scales=True)
plot_comparison_1d(signal_inverted, res_inv, res_std, resid_inv, resid_std, sc, 
                   'Inverted vs. Standard (1D Log)', 'Inverted', 'Standard')
# Out:
# --- Running Test Case 2: Inverted vs. Standard (1D Log) ---
# Automatically determining num_channels for log mode.
# --> Determined num_channels = 5
#
# --- STAGE 1: Performing high-resolution decomposition for scales <= 5.0 ---
# Decomposing across 2 user-specified scales: [ 4.   10.64]
# Running in CONSTRAINED (standard) mode.
# Channel 0: Scale < 4.00 pixels, Iterations: 33
# Channel 1: Scale < 10.64 pixels, Iterations: 202
# Downsampling small-scale results...
#
# --- STAGE 2: Performing fixed-grid decomposition on residual for scales > 5.0 ---
# Decomposing across 3 user-specified scales: [ 7.07 18.8  50.  ]
# Running in CONSTRAINED (standard) mode.
# Channel 0: Scale < 7.07 pixels, Iterations: 33
# Channel 1: Scale < 18.80 pixels, Iterations: 202
# Channel 2: Scale < 50.00 pixels, Iterations: 202
# Automatically determining num_channels for log mode.
# --> Determined num_channels = 5
#
# --- STAGE 1: Performing high-resolution decomposition for scales <= 5.0 ---
# Decomposing across 2 user-specified scales: [ 4.   10.64]
# Running in CONSTRAINED (inverted) mode.
# Channel 0: Scale < 4.00 pixels, Iterations: 33
# Channel 1: Scale < 10.64 pixels, Iterations: 202
# Downsampling small-scale results...
#
# --- STAGE 2: Performing fixed-grid decomposition on residual for scales > 5.0 ---
# Decomposing across 3 user-specified scales: [ 7.07 18.8  50.  ]
# Running in CONSTRAINED (inverted) mode.
# Channel 0: Scale < 7.07 pixels, Iterations: 33
# Channel 1: Scale < 18.80 pixels, Iterations: 202
# Channel 2: Scale < 50.00 pixels, Iterations: 202

# %%
# --- Test Case 3: Upsampled vs. Fixed-Grid Decomposition ---
print("\n--- Running Test Case 3: Upsampled vs. Fixed-Grid (1D Log) ---")
res_up, resid_up, sc = constrained_diffusion_decomposition(
    data=signal_1d, max_scale=40, mode='log', up_sample=True, return_scales=True)
res_noup, resid_noup, _ = constrained_diffusion_decomposition(
    data=signal_1d, max_scale=40, mode='log', up_sample=False, return_scales=True)
plot_comparison_1d(signal_1d, res_up, res_noup, resid_up, resid_noup, sc, 
                   'Upsampled vs. Fixed-Grid (1D Log)', 'Upsampled', 'Fixed Grid')
# Out:
# --- Running Test Case 3: Upsampled vs. Fixed-Grid (1D Log) ---
# Automatically determining num_channels for log mode.
# --> Determined num_channels = 5
#
# --- STAGE 1: Performing high-resolution decomposition for scales <= 5.0 ---
# Decomposing across 2 user-specified scales: [ 4.   10.06]
# Running in CONSTRAINED (standard) mode.
# Channel 0: Scale < 4.00 pixels, Iterations: 33
# Channel 1: Scale < 10.06 pixels, Iterations: 177
# Downsampling small-scale results...
#
# --- STAGE 2: Performing fixed-grid decomposition on residual for scales > 5.0 ---
# Decomposing across 3 user-specified scales: [ 6.32 15.91 40.  ]
# Running in CONSTRAINED (standard) mode.
# Channel 0: Scale < 6.32 pixels, Iterations: 33
# Channel 1: Scale < 15.91 pixels, Iterations: 177
# Channel 2: Scale < 40.00 pixels, Iterations: 177
# Automatically determining num_channels for log mode.
# --> Determined num_channels = 5
#
# --- Performing standard fixed-grid decomposition for all scales ---
# Decomposing across 5 user-specified scales: [ 1.    2.51  6.32 15.91 40.  ]
# Running in CONSTRAINED (standard) mode.
# Channel 0: Scale < 1.00 pixels, Iterations: 33
# Channel 1: Scale < 2.51 pixels, Iterations: 177
# Channel 2: Scale < 6.32 pixels, Iterations: 177
# Channel 3: Scale < 15.91 pixels, Iterations: 177
# Channel 4: Scale < 40.00 pixels, Iterations: 177

# %%
# --- Test Case 4: 2D Unconstrained Decomposition ---
print("\n--- Running Test Case 4: 2D Unconstrained Decomposition ---")
res, resid, sc = constrained_diffusion_decomposition(
    data=image_2d, max_scale=32, mode='log', constrained=False, up_sample=True, return_scales=True)
plot_decomposition_2d(image_2d, res, resid, sc, '2D Decomposition (Unconstrained)')
# Out:
# --- Running Test Case 4: 2D Unconstrained Decomposition ---
# Automatically determining num_channels for log mode.
# --> Determined num_channels = 5
#
# --- STAGE 1: Performing high-resolution decomposition for scales <= 5.0 ---
# Decomposing across 2 user-specified scales: [4.   9.51]
# Running in UNCONSTRAINED (linear diffusion) mode.
# Channel 0: Scale < 4.00 pixels, Iterations: 33
# Channel 1: Scale < 9.51 pixels, Iterations: 155
# Downsampling small-scale results...
#
# --- STAGE 2: Performing fixed-grid decomposition on residual for scales > 5.0 ---
# Decomposing across 3 user-specified scales: [ 5.66 13.45 32.  ]
# Running in UNCONSTRAINED (linear diffusion) mode.
# Channel 0: Scale < 5.66 pixels, Iterations: 33
# Channel 1: Scale < 13.45 pixels, Iterations: 155
# Channel 2: Scale < 32.00 pixels, Iterations: 155
# /var/folders/t_/1c6q66gn5jqg62hwxfkjlb380000gn/T/ipykernel_56439/3451151958.py:110: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout(rect=[0, 0.03, 1, 0.95])

# %%
# --- Test Case 5: 2D Constrained Decomposition ---
print("\n--- Running Test Case 5: 2D Constrained Decomposition ---")
res, resid, sc = constrained_diffusion_decomposition(
    data=image_2d, max_scale=32, mode='log', constrained=True, up_sample=True, return_scales=True)
plot_decomposition_2d(image_2d, res, resid, sc, '2D Decomposition (Constrained)')
# Out:
# --- Running Test Case 5: 2D Constrained Decomposition ---
# Automatically determining num_channels for log mode.
# --> Determined num_channels = 5
#
# --- STAGE 1: Performing high-resolution decomposition for scales <= 5.0 ---
# Decomposing across 2 user-specified scales: [4.   9.51]
# Running in CONSTRAINED (standard) mode.
# Channel 0: Scale < 4.00 pixels, Iterations: 33
# Channel 1: Scale < 9.51 pixels, Iterations: 155
# Downsampling small-scale results...
#
# --- STAGE 2: Performing fixed-grid decomposition on residual for scales > 5.0 ---
# Decomposing across 3 user-specified scales: [ 5.66 13.45 32.  ]
# Running in CONSTRAINED (standard) mode.
# Channel 0: Scale < 5.66 pixels, Iterations: 33
# Channel 1: Scale < 13.45 pixels, Iterations: 155
# Channel 2: Scale < 32.00 pixels, Iterations: 155
# /var/folders/t_/1c6q66gn5jqg62hwxfkjlb380000gn/T/ipykernel_56439/3451151958.py:110: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout(rect=[0, 0.03, 1, 0.95])
